# %%
import sys
sys.path.insert(0, '..')

import wandb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Load Wandb Data

# %%
# Initialize wandb API
api = wandb.Api()

# Get runs from project
project = api.project("collective-architecture")
runs = project.runs

print(f"Found {len(runs)} runs")

# Filter for phase1 runs
phase1_runs = [r for r in runs if 'phase1' in r.tags]
print(f"Phase 1 runs: {len(phase1_runs)}")

# %% [markdown]
# ## 2. Extract Results & Compare Models
#
# See notebook for full analysis sections:
# - Training curves
# - Accuracy comparison
# - Expert output analysis (when available)
# - Inference time measurement (when models are saved)
# - Parameter count verification
